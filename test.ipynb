# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt 
import json
from datetime import datetime, timedelta
import plotly.express as px
import requests

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
tt = [9000, 1200, 8500, 7300, 8200, 7200, 6000, 5500, 2000, 1000, 400]

plt.plot(tt)
