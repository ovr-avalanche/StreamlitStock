# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt 
import json
from datetime import datetime, timedelta
import plotly.express as px

# %%
ticker: yf.ticker = yf.Ticker("AAPL")
stockdata = ticker.history(period="1d", start="2024-01-17", end="2025-01-17")

# %%
fig = px.line(stockdata, x=stockdata.index, y="Close", title='Apple Stock Price')
fig.show()

# %%
stock = 'AAPL'
stockticker = yf.Ticker(stock)
start_date = (datetime.today() - timedelta(days=365)).strftime('%Y-%m-%d')
end_date = datetime.today().strftime('%Y-%m-%d')
stockdata = stockticker.history(period="1d", start=start_date, end=end_date)

# %%
file_path = "stocks.json"
try:
    with open(file_path, "r") as file:
        data = json.load(file)    

except FileNotFoundError:
    print("File not found")
    
print(data)
# Out:
# {'Intel': 'INTC', 'Nvidia': 'NVDA', 'AMD': 'AMD', 'Microsoft': 'MSFT', 'MSCI World': 'URTH', 'MSCI Australia': 'EWA', 'BYD': 'BYDDY', 'Tesla': 'TSLA', 'Apple': 'AAPL', 'Amazon': 'AMZN', 'Google': 'GOOGL', 'Facebook': 'META', '': ''}

# %%
my_dict = {'name': 'John', 'age': 25}
keys = my_dict.keys()
keys
# Out:
# dict_keys(['name', 'age'])

# %%
# put the apple stock data into a pd dataframe
apple_data = apple.history(period="1d", start="1990-01-01", end="2025-01-01")
intel_data = intel.history(period="1d", start="1990-01-01", end="2025-01-01")
# Out:
# $AAPL: possibly delisted; no price data found  (1d 1990-01-01 -> 2025-01-01)
# $INTC: possibly delisted; no price data found  (1d 1990-01-01 -> 2025-01-01)

# %%
class Monster:
    def __init__(self, func):
        self.func = func

    
class Attacks:
    def bite(self):
        print("Monster bites")
    def strike(self):
        print("Monster strikes")

# %%
monster = Monster(Attacks.bite)
monster.func(Attacks)
# Out:
# Monster bites

# %%
type(Attacks().bite) # metho
type(Attacks.bite) # function
# Out:
# function
